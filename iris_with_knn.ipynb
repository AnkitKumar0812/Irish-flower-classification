# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("IRIS.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
X= df[['sepal_length','sepal_width','petal_length','petal_width']]
X.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]>

# %%
y=df['species']
y.head
# Out:
# <bound method NDFrame.head of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
X_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 80            5.5          2.4           3.8          1.1
# 114           5.8          2.8           5.1          2.4
# 14            5.8          4.0           1.2          0.2
# 40            5.0          3.5           1.3          0.3
# 17            5.1          3.5           1.4          0.3

# %%
X_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 133           6.3          2.8           5.1          1.5
# 43            5.0          3.5           1.6          0.6
# 7             5.0          3.4           1.5          0.2
# 144           6.7          3.3           5.7          2.5
# 51            6.4          3.2           4.5          1.5

# %%
y_train.head()
# Out:
# 80     Iris-versicolor
# 114     Iris-virginica
# 14         Iris-setosa
# 40         Iris-setosa
# 17         Iris-setosa
# Name: species, dtype: object

# %%
y_test.head()
# Out:
# 133     Iris-virginica
# 43         Iris-setosa
# 7          Iris-setosa
# 144     Iris-virginica
# 51     Iris-versicolor
# Name: species, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()

# %%
knn_model.n_neighbors
# Out:
# 5

# %%
k = int(len(X) ** (1 / 2))
p=int(len(X))
print(p)
print(k)
# Out:
# 150
# 12

# %%
knn_model = KNeighborsClassifier(n_neighbors = k)
knn_model.n_neighbors
# Out:
# 12

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
y_predicted = knn_model.predict(X_test)
y_predicted
# Out:
# array(['Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predicted)
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_predicted))
# Out:
# [[14  0  0]
#  [ 0 10  0]
#  [ 0  3 18]]

# %%
dc=pd.DataFrame(X_test)
dc['species'] = y_predicted
dc.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width          species
# 133           6.3          2.8           5.1          1.5   Iris-virginica
# 43            5.0          3.5           1.6          0.6      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 95            5.7          3.0           4.2          1.2  Iris-versicolor
# 123           6.3          2.7           4.9          1.8   Iris-virginica
# 142           5.8          2.7           5.1          1.9   Iris-virginica
# 99            5.7          2.8           4.1          1.3  Iris-versicolor
# ...

# %%
plt.title("Given Dataset")
plt.xlabel("Features")
plt.ylabel("Species")
plt.scatter(df['sepal_length'], df['species'], color = 'red', label = 'Sepal Length')
plt.scatter(df['sepal_width'], df['species'], color = 'blue', label = 'Sepal Width')
plt.scatter(df['petal_length'], df['species'], color = 'green', label = 'Petal Length')
plt.scatter(df['petal_width'], df['species'], color = 'yellow', label = 'Petal Width')
plt.legend()
plt.show()

# %%
plt.title("Test Dataset")
plt.xlabel("Features")
plt.ylabel("Species")
plt.scatter(dc['sepal_length'], dc['species'], color = 'red', label = 'Sepal Length')
plt.scatter(dc['sepal_width'], dc['species'], color = 'blue', label = 'Sepal Width')
plt.scatter(dc['petal_length'], dc['species'], color = 'green', label = 'Petal Length')
plt.scatter(dc['petal_width'], dc['species'], color = 'yellow', label = 'Petal Width')
plt.legend()
plt.show()

# %%
plt.title("Given Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = df)
plt.show()

# %%
plt.title("Test Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', data = dc)
plt.show()

# %%
plt.title("Given Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'species', data = df)
plt.show()

# %%
plt.title("Test Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'species', data = dc)
plt.show()

# %%
plt.title("Given Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'species', style = 'species', data = df)
plt.show()

# %%
plt.title("Test Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'species', style = 'species', data = dc)
plt.show()

# %%
plt.title("Given Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'petal_length', data = df)
plt.show()

# %%
plt.title("Test Dataset")
sns.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'petal_length', data = dc)
plt.show()
